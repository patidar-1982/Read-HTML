# %% [markdown]
# # HTML - Read data from html

# %%
import numpy as np
import pandas as pd

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/2011_census_of_India')

# %%
#how many tables are there
len(table)
# Out:
# 13

# %%
#access table
table[1]
# Out:
#         0                      1       2
# 0  ← 2001  9 to 28 February 2011  2021 →

# %%
table[0]
# Out:
#                                   15th censusof India  \
# 0                 ← 2001 9 to 28 February 2011 2021 →
# 1                                              ← 2001
# 2   President of India Pratibha Patil receiving th...
# 3                                 General information
# 4                                             Country
# 5                                           Authority
# 6                                             Website
# 7                                             Results
# 8                                    Total population
# 9                                Most populous ​state
# 10                              Least populous ​state
# 11                                   Scheduled Castes
# 12                                   Scheduled Tribes
#
#                                 15th censusof India.1 Unnamed: 2
# 0                 ← 2001 9 to 28 February 2011 2021 →        NaN
# 1                               9 to 28 February 2011     2021 →
# ...

# %%
#choose specific table using match parameter
table1 = pd.read_html('https://en.wikipedia.org/wiki/2011_census_of_India',match='Population distribution in India by states')

# %%
len(table1)
# Out:
# 1

# %%
df = pd.DataFrame(table1[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-c7eb256513e2> in <module>
# ----> 1 df = pd.DataFrame(table1[1])
#
# IndexError: list index out of range

# %%
df = pd.DataFrame(table1[0])

# %%
df
# Out:
#      Rank State / Union Territory (UT)                         Capital   Type  \
# 0       1                Uttar Pradesh                         Lucknow  State
# 1       2                  Maharashtra                          Mumbai  State
# 2       3                        Bihar                           Patna  State
# 3       4                  West Bengal                         Kolkata  State
# 4       5            Andhra Pradesh[a]                       Hyderabad  State
# 5       6               Madhya Pradesh                          Bhopal  State
# 6       7                   Tamil Nadu                         Chennai  State
# 7       8                    Rajasthan                          Jaipur  State
# 8       9                    Karnataka                       Bengaluru  State
# 9      10                      Gujarat                     Gandhinagar  State
# 10     11                       Odisha                    Bhubaneshwar  State
# ...

# %%
df = df[0:-1]

# %%
df
# Out:
#    Rank State / Union Territory (UT)                         Capital   Type  \
# 0     1                Uttar Pradesh                         Lucknow  State
# 1     2                  Maharashtra                          Mumbai  State
# 2     3                        Bihar                           Patna  State
# 3     4                  West Bengal                         Kolkata  State
# 4     5            Andhra Pradesh[a]                       Hyderabad  State
# 5     6               Madhya Pradesh                          Bhopal  State
# 6     7                   Tamil Nadu                         Chennai  State
# 7     8                    Rajasthan                          Jaipur  State
# 8     9                    Karnataka                       Bengaluru  State
# 9    10                      Gujarat                     Gandhinagar  State
# 10   11                       Odisha                    Bhubaneshwar  State
# ...

# %%
# set index as rank
df.set_index('Rank',inplace=True)

# %%
df
# Out:
#      State / Union Territory (UT)                         Capital   Type  \
# Rank
# 1                   Uttar Pradesh                         Lucknow  State
# 2                     Maharashtra                          Mumbai  State
# 3                           Bihar                           Patna  State
# 4                     West Bengal                         Kolkata  State
# 5               Andhra Pradesh[a]                       Hyderabad  State
# 6                  Madhya Pradesh                          Bhopal  State
# 7                      Tamil Nadu                         Chennai  State
# 8                       Rajasthan                          Jaipur  State
# 9                       Karnataka                       Bengaluru  State
# 10                        Gujarat                     Gandhinagar  State
# 11                         Odisha                    Bhubaneshwar  State
# 12                         Kerala              Thiruvananthapuram  State
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 1 to 35
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   State / Union Territory (UT)  35 non-null     object
#  1   Capital                       35 non-null     object
#  2   Type                          35 non-null     object
#  3   Population                    35 non-null     int64
#  4   % of totalpopula-tion[41]     35 non-null     float64
#  5   Males                         35 non-null     int64
#  6   Females                       35 non-null     int64
#  7   SexRatio [42]                 35 non-null     int64
#  8   Literacyrate (%)              35 non-null     float64
#  9   Rural[43] Population          35 non-null     int64
#  10  Urban[43] Population          35 non-null     int64
#  11  Area[44] (km2)                35 non-null     int64
#  12  Density (1/km2)               35 non-null     int64
# ...

# %%
df.describe()
# Out:
#          Population  % of totalpopula-tion[41]         Males       Females  \
# count  3.500000e+01                  35.000000  3.500000e+01  3.500000e+01
# mean   3.459203e+07                   2.856857  1.780062e+07  1.678422e+07
# std    4.445516e+07                   3.671943  2.305551e+07  2.141356e+07
# min    6.447300e+04                   0.010000  3.312300e+04  3.135000e+04
# 25%    1.421136e+06                   0.115000  7.265260e+05  6.946100e+05
# 50%    1.678794e+07                   1.390000  8.887326e+06  7.800615e+06
# 75%    6.076749e+07                   5.020000  3.122896e+07  2.953854e+07
# max    1.998123e+08                  16.500000  1.044805e+08  9.533183e+07
#
#        SexRatio [42]  Literacyrate (%)  Rural[43] Population  \
# count      35.000000         35.000000          3.500000e+01
# mean      931.228571         77.940286          2.381866e+07
# std        79.883402          8.598837          3.296505e+07
# ...

# %%
df.columns
# Out:
# Index(['State / Union Territory (UT)', 'Capital', 'Type', 'Population',
#        '% of totalpopula-tion[41]', 'Males', 'Females', 'SexRatio [42]',
#        'Literacyrate (%)', 'Rural[43] Population', 'Urban[43] Population',
#        'Area[44] (km2)', 'Density (1/km2)', 'DecadalGrowth%(2001–11)'],
#       dtype='object')

# %%
# rename column name
df.rename(columns={'% of totalpopula-tion[41]':'% of Population'}, inplace=True)
# Out:
# C:\Users\PARI\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df
# Out:
#      State / Union Territory (UT)                         Capital   Type  \
# Rank
# 1                   Uttar Pradesh                         Lucknow  State
# 2                     Maharashtra                          Mumbai  State
# 3                           Bihar                           Patna  State
# 4                     West Bengal                         Kolkata  State
# 5               Andhra Pradesh[a]                       Hyderabad  State
# 6                  Madhya Pradesh                          Bhopal  State
# 7                      Tamil Nadu                         Chennai  State
# 8                       Rajasthan                          Jaipur  State
# 9                       Karnataka                       Bengaluru  State
# 10                        Gujarat                     Gandhinagar  State
# 11                         Odisha                    Bhubaneshwar  State
# 12                         Kerala              Thiruvananthapuram  State
# ...

# %%
df.describe()
# Out:
#          Population  % of Population         Males       Females  \
# count  3.500000e+01        35.000000  3.500000e+01  3.500000e+01
# mean   3.459203e+07         2.856857  1.780062e+07  1.678422e+07
# std    4.445516e+07         3.671943  2.305551e+07  2.141356e+07
# min    6.447300e+04         0.010000  3.312300e+04  3.135000e+04
# 25%    1.421136e+06         0.115000  7.265260e+05  6.946100e+05
# 50%    1.678794e+07         1.390000  8.887326e+06  7.800615e+06
# 75%    6.076749e+07         5.020000  3.122896e+07  2.953854e+07
# max    1.998123e+08        16.500000  1.044805e+08  9.533183e+07
#
#        SexRatio [42]  Literacyrate (%)  Rural[43] Population  \
# count      35.000000         35.000000          3.500000e+01
# mean      931.228571         77.940286          2.381866e+07
# std        79.883402          8.598837          3.296505e+07
# min       618.000000         61.800000          1.412100e+04
# 25%       903.500000         71.235000          7.480705e+05
# ...

# %%
df.columns
# Out:
# Index(['State / Union Territory (UT)', 'Capital', 'Type', 'Population',
#        '% of Population', 'Males', 'Females', 'SexRatio [42]',
#        'Literacyrate (%)', 'Rural[43] Population', 'Urban[43] Population',
#        'Area[44] (km2)', 'Density (1/km2)', 'DecadalGrowth%(2001–11)'],
#       dtype='object')

# %%
df.rename(columns={'State / Union Territory (UT)':'State/UT',
                  'SexRatio [42]':'SexRatio',
                  'Rural[43] Population':'Population-Rural',
                  'Urban[43] Population':'Population-Urban',
                  'Area[44] (km2)':'Area_sqkm',
                   'DecadalGrowth%(2001–11)': 'Growth_2001_to_2011'},inplace=True)
# Out:
# C:\Users\PARI\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df.columns
# Out:
# Index(['State/UT', 'Capital', 'Type', 'Population', '% of Population', 'Males',
#        'Females', 'SexRatio', 'Literacyrate (%)', 'Population-Rural',
#        'Population-Urban', 'Area_sqkm', 'Density (1/km2)',
#        'Growth_2001_to_2011'],
#       dtype='object')

# %%
df.sort_values('State/UT')
# Out:
#                          State/UT                         Capital   Type  \
# Rank
# 32    Andaman and Nicobar Islands                      Port Blair     UT
# 5               Andhra Pradesh[a]                       Hyderabad  State
# 27              Arunachal Pradesh                        Itanagar  State
# 14                          Assam                          Dispur  State
# 3                           Bihar                           Patna  State
# 30                     Chandigarh                      Chandigarh     UT
# 16                   Chhattisgarh                          Raipur  State
# 33         Dadra and Nagar Haveli                        Silvassa     UT
# 34                  Daman and Diu                           Daman     UT
# 18                          Delhi                           Delhi     UT
# 26                            Goa                          Panaji  State
# 10                        Gujarat                     Gandhinagar  State
# ...

# %%
df.sort_values('State/UT',ascending=False)
# Out:
#                          State/UT                         Capital   Type  \
# Rank
# 4                     West Bengal                         Kolkata  State
# 20                    Uttarakhand                        Dehradun  State
# 1                   Uttar Pradesh                         Lucknow  State
# 22                        Tripura                        Agartala  State
# 7                      Tamil Nadu                         Chennai  State
# 31                         Sikkim                         Gangtok  State
# 8                       Rajasthan                          Jaipur  State
# 15                         Punjab                      Chandigarh  State
# 28                     Puducherry                     Pondicherry     UT
# 11                         Odisha                    Bhubaneshwar  State
# 25                       Nagaland                          Kohima  State
# 29                        Mizoram                          Aizawl  State
# ...

# %%
df.to_excel("Census-2011.xlsx")

# %%
df.groupby('Type')['Type'].count()
# Out:
# Type
# State    28
# UT        7
# Name: Type, dtype: int64

# %%
df.Type.unique()
# Out:
# array(['State', 'UT'], dtype=object)

# %%
df.Type.nunique()
# Out:
# 2

# %%
df.Type.unique
# Out:
# <bound method Series.unique of Rank
# 1     State
# 2     State
# 3     State
# 4     State
# 5     State
# 6     State
# 7     State
# 8     State
# 9     State
# 10    State
# 11    State
# 12    State
# 13    State
# 14    State
# 15    State
# 16    State
# 17    State
# 18       UT
# 19    State
# 20    State
# 21    State
# 22    State
# 23    State
# 24    State
# 25    State
# 26    State
# 27    State
# 28       UT
# 29    State
# 30       UT
# 31    State
# 32       UT
# 33       UT
# 34       UT
# 35       UT
# Name: Type, dtype: object>

# %%
#choose specific table using match parameter
table2 = pd.read_html('https://en.wikipedia.org/wiki/2011_census_of_India',match='First, Second, and Third languages by number of speakers in India')

# %%
len(table2)
# Out:
# 1

# %%
table2[0]
# Out:
#      Language  First languagespeakers[82]  \
# 0       Hindi                   528347193
# 1     English                      259678
# 2     Bengali                    97237669
# 3     Marathi                    83026680
# 4      Telugu                    81127740
# 5       Tamil                    69026881
# 6    Gujarati                    55492554
# 7        Urdu                    50772631
# 8     Kannada                    43706512
# 9        Odia                    37521324
# 10  Malayalam                    34838819
# 11    Punjabi                    33124726
# 12   Sanskrit                       24821
#
#    First languagespeakers as a percentage of total population  \
# 0                                               43.63
# 1                                                0.02
# 2                                                 8.3
# 3                                                7.09
# 4                                                6.93
# ...

# %% [markdown]
# # convert dataframe into html page

# %%
# Fastest 100 meters runners
fastest_100m = pd.DataFrame({
    'Rank': range(1, 6),
    'Runner': ['Usain Bolt', 'Tyson Gay', 'Yohan Blake', 'Asafa Powell', 'Justin Gatlin'],
    'Time': [9.58, 9.69, 9.69, 9.72, 9.74], # seconds
    'Country': ['Jamaica', 'USA', 'Jamaica', 'Jamaica', 'USA']
})
print(fastest_100m)
fastest_100m = fastest_100m.set_index('Rank')
fastest_100m
# Out:
#    Rank         Runner  Time  Country
# 0     1     Usain Bolt  9.58  Jamaica
# 1     2      Tyson Gay  9.69      USA
# 2     3    Yohan Blake  9.69  Jamaica
# 3     4   Asafa Powell  9.72  Jamaica
# 4     5  Justin Gatlin  9.74      USA
#              Runner  Time  Country
# Rank
# 1        Usain Bolt  9.58  Jamaica
# 2         Tyson Gay  9.69      USA
# 3       Yohan Blake  9.69  Jamaica
# 4      Asafa Powell  9.72  Jamaica
# 5     Justin Gatlin  9.74      USA

# %% [markdown]
# #### The DataFrame method to_html() will return the content formatted as HTML code. You can use this code to render the DataFrame on any web page.

# %%
# Convert DataFrame to an HTML table
fastest_100m.to_html("coding.html")

# %% [markdown]
# ## Reading tables from a file

# %%
t1 = pd.read_html('htmlforpractic.html')

# %%
t1[0]
# Out:
#          Full Name           Position Salary
# 0       Bill Gates  Founder MIcrosoft  $1000
# 1       Steve Jobs      Founder Apple  $1200
# 2  Mark Zuckerberg   Founder Facebook  $1300

# %%
t2 = pd.DataFrame(t1[0])

# %%
t2
# Out:
#          Full Name           Position Salary
# 0       Bill Gates  Founder MIcrosoft  $1000
# 1       Steve Jobs      Founder Apple  $1200
# 2  Mark Zuckerberg   Founder Facebook  $1300
